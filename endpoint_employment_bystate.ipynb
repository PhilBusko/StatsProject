# %% [markdown]
# # CDE - Explore Endpoints

# %%
import os
import pandas as pd

import crime_helper as ch

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Import Data

# %%
# load the lookup data

STATE = 'data/state.csv'
OFFENSE_SHORT = 'data/offense_short.csv'
YEAR_SINCE = 2010
YEAR_UNTIL = 2011

# %%
state_df = pd.read_csv(STATE)
state_df.state_abbr.to_list()
state_df.head()
# Out:
# ['AK',
#  'AL',
#  'AR',
#  'AS',
#  'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'CZ',
#  'DC',
#  'DE',
#  'FL',
#  'GA',
#  'GM',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'NE',
#  'NC',
#  'ND',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'PR',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY',
#  'MP',
#  'OT',
#  'VI']
#    region_code state_abbr  state_fips_code  state_id      state_name
# 0  4            AK         2.0              1         Alaska
# 1  3            AL         1.0              2         Alabama
# 2  3            AR         5.0              3         Arkansas
# 3  99           AS         60.0             4         American Samoa
# 4  4            AZ         4.0              5         Arizona

# %%
offense_df = pd.read_csv(OFFENSE_SHORT)
offense_df.offense_type.to_list()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ad3686c1e7dc> in <module>
# ----> 1 offense_df = pd.read_csv(OFFENSE_SHORT)
#       2 offense_df.offense_type.to_list()
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/offense_short.csv' does not exist: b'data/offense_short.csv'

# %%
# examine data for a random row

random_state = state_df.loc[10]['state_abbr']
# random_offense = offense_df.loc[4]['offense_type']
random_state
# random_offense
# Out:
# 'DE'

# %%
config = {
    '{since}': '2010',
    '{stateAbbr}': random_state,
    '{until}' : '2018'
}
employment = ch.get_json(ch.EMPLOYMENT_STATE, config)
# Out:
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9

# %%
# loop over all states and retrieve info via API
# aggregate the info into employment_list, which will be later converted into a dataframe

employment_list = []
for state in state_df.state_abbr.to_list():
    config = {
        '{since}': '2010',
        '{stateAbbr}': state,
        '{until}' : '2018'
        }
    employment = ch.get_json(ch.EMPLOYMENT_STATE, config)
    employment_list += employment
# Out:
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9
# {'count': 9, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 9

# %%
employment_df = pd.DataFrame(employment_list)
employment_df.head()
len(employment_df)
# Out:
#    agency_count_pe_submitting  civilian_ct csv_header  data_year  \
# 0  58                          1304         None       2010
# 1  56                          1287         None       2011
# 2  59                          877          None       2012
# 3  66                          898          None       2013
# 4  68                          1316         None       2014
#
#    female_civilian_ct  female_officer_ct  female_total_ct  male_civilian_ct  \
# 0  812                 434                1246             492
# 1  795                 424                1219             492
# 2  558                 328                886              319
# 3  575                 352                927              323
# 4  744                 297                1041             572
#
#    male_officer_ct  male_total_ct  pe_ct_per_1000  population state_abbr  \
# 0  3128             3620           5.32            915164      DE
# 1  3054             3546           5.16            923759      DE
# 2  2028             2347           3.46            934970      DE
# 3  2125             2448           3.57            944369      DE
# 4  2552             3124           4.36            954220      DE
#
#    state_id state_name  total_pe_ct
# 0  11        Delaware   4866
# 1  11        Delaware   4765
# 2  11        Delaware   3233
# 3  11        Delaware   3375
# 4  11        Delaware   4165
# 522

# %%
# remove unnecessery column
employment_df.drop(['csv_header', 'state_id'], inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-5fc121356112> in <module>
#       1 # remove unnecessery column
# ----> 2 employment_df.drop(['csv_header', 'state_id'], inplace = True, axis = 1)
#       3 employment_df.head()
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['csv_header' 'state_id'] not found in axis"

# %%
employment_df.head()
# Out:
#    agency_count_pe_submitting  civilian_ct  data_year  female_civilian_ct  \
# 0  58                          1304         2010       812
# 1  56                          1287         2011       795
# 2  59                          877          2012       558
# 3  66                          898          2013       575
# 4  68                          1316         2014       744
#
#    female_officer_ct  female_total_ct  male_civilian_ct  male_officer_ct  \
# 0  434                1246             492               3128
# 1  424                1219             492               3054
# 2  328                886              319               2028
# 3  352                927              323               2125
# 4  297                1041             572               2552
#
#    male_total_ct  pe_ct_per_1000  population state_abbr state_name  \
# 0  3620           5.32            915164      DE         Delaware
# 1  3546           5.16            923759      DE         Delaware
# 2  2347           3.46            934970      DE         Delaware
# 3  2448           3.57            944369      DE         Delaware
# 4  3124           4.36            954220      DE         Delaware
#
#    total_pe_ct
# 0  4866
# 1  4765
# 2  3233
# 3  3375
# 4  4165

# %%
# rename colum 'key' to 'gender', 'data_year' to 'year'
employment_df.rename(columns={'agency_count_pe_submitting': 'agency_ct', 'data_year': 'year'}, inplace=True)
employment_df.head(2)
# Out:
#    agency_ct  civilian_ct  year  female_civilian_ct  female_officer_ct  \
# 0  58         1304         2010  812                 434
# 1  56         1287         2011  795                 424
#
#    female_total_ct  male_civilian_ct  male_officer_ct  male_total_ct  \
# 0  1246             492               3128             3620
# 1  1219             492               3054             3546
#
#    pe_ct_per_1000  population state_abbr state_name  total_pe_ct
# 0  5.32            915164      DE         Delaware   4866
# 1  5.16            923759      DE         Delaware   4765

# %% [markdown]
# ## Export to csv

# %%
save_path = r'data/employment_state.csv'
employment_df.to_csv(save_path, index=False)
f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
# Out:
# '0.04 mb'

# %% [markdown]
# # Employment Endpoint

# %%
import os
import pandas as pd

import crime_helper as ch

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Import Data

# %%
# load the lookup data

STATE = 'data/lookup_state.csv'
OFFENSE_SHORT = 'data/lookup_offense_short.csv'
YEAR_SINCE = '2000'
YEAR_UNTIL = '2018'

# %%
state_df = pd.read_csv(STATE)
state_df.state_abbr.to_list()[:5]
state_df.head()
# Out:
# ['AK', 'AL', 'AR', 'AS', 'AZ']
#    region_code state_abbr  state_fips_code  state_id      state_name
# 0  4            AK         2.0              1         Alaska
# 1  3            AL         1.0              2         Alabama
# 2  3            AR         5.0              3         Arkansas
# 3  99           AS         60.0             4         American Samoa
# 4  4            AZ         4.0              5         Arizona

# %%
offense_df = pd.read_csv(OFFENSE_SHORT)
offense_df.offense_type.to_list()
# Out:
# ['aggravated-assault',
#  'burglary',
#  'larceny',
#  'motor-vehicle-theft',
#  'homicide',
#  'rape',
#  'robbery',
#  'arson',
#  'violent-crime',
#  'property-crime']

# %%
# examine data for a random row

random_state = state_df.loc[10]['state_abbr']
# random_offense = offense_df.loc[4]['offense_type']
random_state
# random_offense
# Out:
# 'DE'

# %%
config = {
    '{stateAbbr}': random_state,
    '{since}': YEAR_SINCE,
    '{until}' : YEAR_UNTIL
}
employment = ch.get_json(ch.EMPLOYMENT_STATE, config)
# Out:
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19

# %%
# loop over all states and retrieve info via API
# aggregate the info into employment_list, which will be later converted into a dataframe

employment_list = []
for state in state_df.state_abbr.to_list():
    config = {
        '{stateAbbr}': state,
        '{since}': YEAR_SINCE,
        '{until}' : YEAR_UNTIL
    }
    employment = ch.get_json(ch.EMPLOYMENT_STATE, config)
    employment_list += employment
# Out:
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19

# %%
employment_df = pd.DataFrame(employment_list)
employment_df.head()
len(employment_df)
# Out:
#    agency_count_pe_submitting  civilian_ct csv_header  data_year  \
# 0  32                          675.0        None       2000
# 1  33                          661.0        None       2001
# 2  33                          701.0        None       2002
# 3  33                          682.0        None       2003
# 4  34                          688.0        None       2004
#
#    female_civilian_ct  female_officer_ct  female_total_ct  male_civilian_ct  \
# 0  475.0               103.0              578.0            200.0
# 1  463.0               107.0              570.0            198.0
# 2  482.0               112.0              594.0            219.0
# 3  470.0               111.0              581.0            212.0
# 4  470.0               127.0              597.0            218.0
#
#    male_officer_ct  male_total_ct  pe_ct_per_1000  population state_abbr  \
# 0  1055.0           1255.0         2.92            626932      AK
# 1  1097.0           1295.0         2.94            634892      AK
# 2  1091.0           1310.0         2.96            643893      AK
# 3  1063.0           1275.0         2.86            648921      AK
# 4  1125.0           1343.0         2.96            655932      AK
#
#    state_id state_name  total_pe_ct
# 0  1         Alaska     1833.0
# 1  1         Alaska     1865.0
# 2  1         Alaska     1904.0
# 3  1         Alaska     1856.0
# 4  1         Alaska     1940.0
# 1102

# %%
# remove unnecessery column
employment_df.drop(['csv_header', 'state_id'], inplace = True, axis = 1)

# %%
employment_df.head()
# Out:
#    agency_count_pe_submitting  civilian_ct  data_year  female_civilian_ct  \
# 0  32                          675.0        2000       475.0
# 1  33                          661.0        2001       463.0
# 2  33                          701.0        2002       482.0
# 3  33                          682.0        2003       470.0
# 4  34                          688.0        2004       470.0
#
#    female_officer_ct  female_total_ct  male_civilian_ct  male_officer_ct  \
# 0  103.0              578.0            200.0             1055.0
# 1  107.0              570.0            198.0             1097.0
# 2  112.0              594.0            219.0             1091.0
# 3  111.0              581.0            212.0             1063.0
# 4  127.0              597.0            218.0             1125.0
#
#    male_total_ct  pe_ct_per_1000  population state_abbr state_name  \
# 0  1255.0         2.92            626932      AK         Alaska
# 1  1295.0         2.94            634892      AK         Alaska
# 2  1310.0         2.96            643893      AK         Alaska
# 3  1275.0         2.86            648921      AK         Alaska
# 4  1343.0         2.96            655932      AK         Alaska
#
#    total_pe_ct
# 0  1833.0
# 1  1865.0
# 2  1904.0
# 3  1856.0
# 4  1940.0

# %%
# rename colum 'key' to 'gender', 'data_year' to 'year'
employment_df.rename(columns={'agency_count_pe_submitting': 'agency_ct', 'data_year': 'year'}, inplace=True)
employment_df.head(2)
# Out:
#    agency_ct  civilian_ct  year  female_civilian_ct  female_officer_ct  \
# 0  32         675.0        2000  475.0               103.0
# 1  33         661.0        2001  463.0               107.0
#
#    female_total_ct  male_civilian_ct  male_officer_ct  male_total_ct  \
# 0  578.0            200.0             1055.0           1255.0
# 1  570.0            198.0             1097.0           1295.0
#
#    pe_ct_per_1000  population state_abbr state_name  total_pe_ct
# 0  2.92            626932      AK         Alaska     1833.0
# 1  2.94            634892      AK         Alaska     1865.0

# %%
# looking for null values, removing states with null values
states_to_remove = employment_df.loc[employment_df.isna().any(axis = 1)].state_name.unique()
states_to_remove
# Out:
# array(['American Samoa', 'Canal Zone', 'Guam', 'Puerto Rico',
#        'Mariana Islands', 'Other', 'U.S. Virgin Islands'], dtype=object)

# %%
# remove the states with null values
for state in states_to_remove:
    employment_df = employment_df.loc[(employment_df.state_name != state)]

# %%
employment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 969 entries, 0 to 1044
# Data columns (total 14 columns):
# agency_ct             969 non-null int64
# civilian_ct           969 non-null float64
# year                  969 non-null int64
# female_civilian_ct    969 non-null float64
# female_officer_ct     969 non-null float64
# female_total_ct       969 non-null float64
# male_civilian_ct      969 non-null float64
# male_officer_ct       969 non-null float64
# male_total_ct         969 non-null float64
# pe_ct_per_1000        969 non-null float64
# population            969 non-null int64
# state_abbr            969 non-null object
# state_name            969 non-null object
# total_pe_ct           969 non-null float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 113.6+ KB

# %%
employment_df.groupby(['state_name']).count()[['year']].reset_index()
# Out:
#               state_name  year
# 0   Alabama               19
# 1   Alaska                19
# 2   Arizona               19
# 3   Arkansas              19
# 4   California            19
# 5   Colorado              19
# 6   Connecticut           19
# 7   Delaware              19
# 8   District of Columbia  19
# 9   Florida               19
# 10  Georgia               19
# 11  Hawaii                19
# 12  Idaho                 19
# 13  Illinois              19
# 14  Indiana               19
# 15  Iowa                  19
# 16  Kansas                19
# 17  Kentucky              19
# 18  Louisiana             19
# 19  Maine                 19
# 20  Maryland              19
# 21  Massachusetts         19
# 22  Michigan              19
# 23  Minnesota             19
# 24  Mississippi           19
# 25  Missouri              19
# 26  Montana               19
# 27  Nebraska              19
# 28  Nevada                19
# 29  New Hampshire         19
# 30  New Jersey            19
# 31  New Mexico            19
# 32  New York              19
# 33  North Carolina        19
# 34  North Dakota          19
# 35  Ohio                  19
# 36  Oklahoma              19
# 37  Oregon                19
# 38  Pennsylvania          19
# 39  Rhode Island          19
# 40  South Carolina        19
# 41  South Dakota          19
# 42  Tennessee             19
# 43  Texas                 19
# 44  Utah                  19
# 45  Vermont               19
# 46  Virginia              19
# 47  Washington            19
# 48  West Virginia         19
# 49  Wisconsin             19
# 50  Wyoming               19

# %% [markdown]
# ## Export to csv

# %%
save_path = r'data/employment_state.csv'
employment_df.to_csv(save_path, index=False)
f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
# Out:
# '0.09 mb'

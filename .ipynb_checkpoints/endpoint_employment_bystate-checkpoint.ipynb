# %% [markdown]
# # Employment Endpoint

# %%
import os
import pandas as pd

import crime_helper as ch

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Import Data

# %%
# load the lookup data

STATE = 'data/lookup_state.csv'
OFFENSE_SHORT = 'data/lookup_offense_short.csv'
YEAR_SINCE = '2000'
YEAR_UNTIL = '2018'

# %%
state_df = pd.read_csv(STATE)
state_df.state_abbr.to_list()
state_df.head()
# Out:
# ['AK',
#  'AL',
#  'AR',
#  'AS',
#  'AZ',
#  'CA',
#  'CO',
#  'CT',
#  'CZ',
#  'DC',
#  'DE',
#  'FL',
#  'GA',
#  'GM',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'NE',
#  'NC',
#  'ND',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'PR',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY',
#  'MP',
#  'OT',
#  'VI']
#    region_code state_abbr  state_fips_code  state_id      state_name
# 0  4            AK         2.0              1         Alaska
# 1  3            AL         1.0              2         Alabama
# 2  3            AR         5.0              3         Arkansas
# 3  99           AS         60.0             4         American Samoa
# 4  4            AZ         4.0              5         Arizona

# %%
offense_df = pd.read_csv(OFFENSE_SHORT)
offense_df.offense_type.to_list()
# Out:
# ['aggravated-assault',
#  'burglary',
#  'larceny',
#  'motor-vehicle-theft',
#  'homicide',
#  'rape',
#  'robbery',
#  'arson',
#  'violent-crime',
#  'property-crime']

# %%
# examine data for a random row

random_state = state_df.loc[10]['state_abbr']
# random_offense = offense_df.loc[4]['offense_type']
random_state
# random_offense
# Out:
# 'DE'

# %%
config = {
    '{stateAbbr}': random_state,
    '{since}': YEAR_SINCE,
    '{until}' : YEAR_UNTIL
}
employment = ch.get_json(ch.EMPLOYMENT_STATE, config)
# Out:
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19

# %%
# loop over all states and retrieve info via API
# aggregate the info into employment_list, which will be later converted into a dataframe

employment_list = []
for state in state_df.state_abbr.to_list():
    config = {
        '{stateAbbr}': state,
        '{since}': YEAR_SINCE,
        '{until}' : YEAR_UNTIL
    }
    employment = ch.get_json(ch.EMPLOYMENT_STATE, config)
    employment_list += employment
# Out:
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19
# {'count': 19, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 19

# %%
employment_df = pd.DataFrame(employment_list)
employment_df.head()
len(employment_df)
# Out:
#    agency_count_pe_submitting  civilian_ct csv_header  data_year  \
# 0  53                          1013         None       2000
# 1  62                          1120         None       2001
# 2  64                          1150         None       2002
# 3  60                          1257         None       2003
# 4  54                          1161         None       2004
#
#    female_civilian_ct  female_officer_ct  female_total_ct  male_civilian_ct  \
# 0  631                 278                909              382
# 1  694                 323                1017             426
# 2  714                 338                1052             436
# 3  813                 399                1212             444
# 4  697                 348                1045             464
#
#    male_officer_ct  male_total_ct  pe_ct_per_1000  population state_abbr  \
# 0  2371             2753           4.54            806621      DE
# 1  2468             2894           4.76            820963      DE
# 2  2761             3197           5.06            839193      DE
# 3  2625             3069           5.08            843255      DE
# 4  2561             3025           4.76            854779      DE
#
#    state_id state_name  total_pe_ct
# 0  11        Delaware   3662
# 1  11        Delaware   3911
# 2  11        Delaware   4249
# 3  11        Delaware   4281
# 4  11        Delaware   4070
# 1102

# %%
# remove unnecessery column
employment_df.drop(['csv_header', 'state_id'], inplace = True, axis = 1)

# %%
employment_df.head()
# Out:
#    agency_count_pe_submitting  civilian_ct  data_year  female_civilian_ct  \
# 0  53                          1013         2000       631
# 1  62                          1120         2001       694
# 2  64                          1150         2002       714
# 3  60                          1257         2003       813
# 4  54                          1161         2004       697
#
#    female_officer_ct  female_total_ct  male_civilian_ct  male_officer_ct  \
# 0  278                909              382               2371
# 1  323                1017             426               2468
# 2  338                1052             436               2761
# 3  399                1212             444               2625
# 4  348                1045             464               2561
#
#    male_total_ct  pe_ct_per_1000  population state_abbr state_name  \
# 0  2753           4.54            806621      DE         Delaware
# 1  2894           4.76            820963      DE         Delaware
# 2  3197           5.06            839193      DE         Delaware
# 3  3069           5.08            843255      DE         Delaware
# 4  3025           4.76            854779      DE         Delaware
#
#    total_pe_ct
# 0  3662
# 1  3911
# 2  4249
# 3  4281
# 4  4070

# %%
# rename colum 'key' to 'gender', 'data_year' to 'year'
employment_df.rename(columns={'agency_count_pe_submitting': 'agency_ct', 'data_year': 'year'}, inplace=True)
employment_df.head(2)
# Out:
#    agency_ct  civilian_ct  year  female_civilian_ct  female_officer_ct  \
# 0  53         1013         2000  631                 278
# 1  62         1120         2001  694                 323
#
#    female_total_ct  male_civilian_ct  male_officer_ct  male_total_ct  \
# 0  909              382               2371             2753
# 1  1017             426               2468             2894
#
#    pe_ct_per_1000  population state_abbr state_name  total_pe_ct
# 0  4.54            806621      DE         Delaware   3662
# 1  4.76            820963      DE         Delaware   3911

# %%
# looking for null values, removing states with null values
states_to_remove = employment_df.loc[employment_df.isna().any(axis = 1)].state_name.unique()
states_to_remove
# Out:
# array([], dtype=object)

# %%
# remove the states with null values
for state in states_to_remove:
    employment_df = employment_df.loc[(employment_df.state_name != state)]

# %%
employment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 14 columns):
# agency_ct             1102 non-null int64
# civilian_ct           1102 non-null int64
# year                  1102 non-null int64
# female_civilian_ct    1102 non-null int64
# female_officer_ct     1102 non-null int64
# female_total_ct       1102 non-null int64
# male_civilian_ct      1102 non-null int64
# male_officer_ct       1102 non-null int64
# male_total_ct         1102 non-null int64
# pe_ct_per_1000        1102 non-null float64
# population            1102 non-null int64
# state_abbr            1102 non-null object
# state_name            1102 non-null object
# total_pe_ct           1102 non-null int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 120.6+ KB

# %% [markdown]
# ## Export to csv

# %%
save_path = r'data/employment_state.csv'
employment_df.to_csv(save_path, index=False)
f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
# Out:
# '0.08 mb'

# %% [markdown]
# # CDE - Explore Endpoints

# %%
import os
import pandas as pd

import crime_helper as ch

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Import Data

# %%
# load the lookup data

STATE = 'data/state.csv'
OFFENSE_SHORT = 'data/offense_short.csv'
YEAR_SINCE = 2010
YEAR_UNTIL = 2011
AGENCY = 'data/agency.csv'

# %%
state_df = pd.read_csv(STATE)
state_df.head()
# Out:
#    region_code state_abbr  state_fips_code  state_id      state_name
# 0  4            AK         2.0              1         Alaska
# 1  3            AL         1.0              2         Alabama
# 2  3            AR         5.0              3         Arkansas
# 3  99           AS         60.0             4         American Samoa
# 4  4            AZ         4.0              5         Arizona

# %%
agency_df = pd.read_csv(AGENCY)
agency_array = (agency_df.ori.to_list())

# %%
offense_df = pd.read_csv(OFFENSE_SHORT)
offense_df.head()
# Out:
#           offense_type
# 0  aggravated-assault
# 1  burglary
# 2  larceny
# 3  motor-vehicle-theft
# 4  homicide

# %%
# examine data for a random row

random_state = state_df.loc[10]['state_abbr']
# random_offense = offense_df.loc[4]['offense_type']
random_state
# random_offense
random_ori = agency_df.ori.loc[4]
random_ori
# Out:
# 'DE'
# 'AK0010500'

# %%
config = {
    '{ori}': random_ori,
    '{since}': '2018',
    '{until}' : '2018'
    }
employment = ch.get_json(ch.EMPLOYMENT_AGENCY, config)
# Out:
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1

# %%
employment_2018 = []
for agency in agency_array:
    config = {
        '{ori}': agency,
        '{since}': '2018',
        '{until}' : '2018'
        }
    employment = ch.get_json(ch.EMPLOYMENT_AGENCY, config)
    employment_2018.append(employment[0])
    
employment_2018[0:5]
# Out:
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0010900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0011900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0012800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0013000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0013100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0013200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0013300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0013500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0014200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0014300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0014500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0014600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0015000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0015200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AK0015600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AKAST0100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0010900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0011900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0012900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0013200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0013400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0013500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0014000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0014100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0014500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0020800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0021200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0021300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0021400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0021500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0021700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0030000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0030100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0030500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0030600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0030700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0030800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0031400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0040000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0040100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0040200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0050900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0051000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0051100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0051200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0051300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0060000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0060100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0060200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0060300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0060400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0060700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0070000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0070100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0070200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0070300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0070400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0080000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0080100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0080200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0080300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0080400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0080500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0090000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0090100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0100000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0100100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0100200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0100300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0110800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0120000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0120100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0120200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0120400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0130000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0130100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0130200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0130300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0140000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0140100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0140200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0140300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0140400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0150000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0150100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0150200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0160000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0160100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0160200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0160300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0160600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0170000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0170100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0170200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0180000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0180100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0180200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0190000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0190100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0190200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0190300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0190400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0200800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0210000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0210100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0210200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0210300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0220000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0220100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0230800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0240000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0240100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0240200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0240300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0250000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0250100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0250200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0250500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0260900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0270000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0270100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0270200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0280800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0281000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0281100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0281200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0281300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0281400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0290700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0300000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0300100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0300200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0300300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0300400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0310900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0311000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0312200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0320000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0320100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0320200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0330000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0330100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0330200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0330300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0330500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0340000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0340100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0340200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0340300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0340400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0350000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0350100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0360000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0360100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0360200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0370000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0370100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0370200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0370300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0380900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0390900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0400000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0400100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0400200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0400300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0400400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0410800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0420600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0430000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0430100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0430200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/AL0440000/2018/2018
# ...
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165A00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165F9E/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165H9E/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165K00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165M00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0165N00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166A00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166B00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166C00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166L00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0166M00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167A00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167B00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0167E00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168A00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168B00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0168C00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169A00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169B00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169C00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169D00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169E00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169F00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169G00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169K00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0169W9E/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL016AB9E/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL016AC9E/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL016PP00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL016PS0X/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL016SL00/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0170000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0170100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0170200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0170300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0170400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0180000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0180100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0180200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190400/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190500/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190600/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190700/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190800/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0190900/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0191000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0191100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0191300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0200000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0200100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0200200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0210000/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0210100/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0210200/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0210300/2018/2018
# {'count': 1, 'page': 0, 'pages': 1, 'per_page': 0}
# page 0: len 1
# https://api.usa.gov/crime/fbi/sapi//api/police-employment/agencies/IL0210400/2018/2018

# %%
df_emp = pd.DataFrame(employment)
df_emp
employment[0]
# Out:
#   agency_name_edit agency_type_name  civilian_ct  \
# 0  KODIAK PD        Borough          24
#
#                                                                                                                                                                                                                                csv_header  \
# 0  data_year,ori,state_abbr,agency_name_edit,agency_type_name,ncic_agency_name,civilian_ct,female_civilian_ct,female_officer_ct,female_total_ct,male_civilian_ct,male_officer_ct,male_total_ct,population,police_emp_per_1000,total_pe_ct
#
#    data_year  female_civilian_ct  female_officer_ct  female_total_ct  \
# 0  2018       11                  1                  12
#
#    male_civilian_ct  male_officer_ct  male_total_ct ncic_agency_name  \
# 0  13                16               29             KODIAK PD
#
#          ori  pe_ct_per_1000  population state_abbr  total_pe_ct
# 0  AK0010500  6.84            5995        AK         41
# {'data_year': 2018,
#  'civilian_ct': 24,
#  'female_civilian_ct': 11,
#  'female_officer_ct': 1,
#  'female_total_ct': 12,
#  'male_civilian_ct': 13,
#  'male_officer_ct': 16,
#  'male_total_ct': 29,
#  'population': 5995,
#  'total_pe_ct': 41,
#  'ori': 'AK0010500',
#  'ncic_agency_name': 'KODIAK PD',
#  'agency_name_edit': 'KODIAK PD',
#  'agency_type_name': 'Borough',
#  'state_abbr': 'AK',
#  'csv_header': 'data_year,ori,state_abbr,agency_name_edit,agency_type_name,ncic_agency_name,civilian_ct,female_civilian_ct,female_officer_ct,female_total_ct,male_civilian_ct,male_officer_ct,male_total_ct,population,police_emp_per_1000,total_pe_ct',
#  'pe_ct_per_1000': 6.84}

# %% [markdown]
# ## Export to csv

# %%
save_path = r'data/file_clean.csv'
file_df.to_csv(save_path, index=False)
f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-275d738ddbb9> in <module>
#       1 save_path = r'data/file_clean.csv'
# ----> 2 file_df.to_csv(save_path, index=False)
#       3 f'{round(os.path.getsize(save_path) /1e6, 2)} mb'
#
# NameError: name 'file_df' is not defined

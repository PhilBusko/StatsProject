# %% [markdown]
# # Analysis: Arrests ANOVA by Region

# %% [markdown]
# Workflow: 3 <br>
# Goal: Run ANOVA analysis on arrest / population, to compare regions. <br>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import crime_helper as ch

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Initial Setup

# %%
ARREST_FILE = 'data/arrest_tkm_state.csv'
EMPLOYMENT_FILE = 'data/employment_state.csv'
OFFENDER_FILE = 'data/offender_tkm_state.csv'
OFFENSE_FILE = 'data/offense_tkm_state.csv'
VICTIM_FILE = 'data/victim_tkm_state.csv'
STATE_FILE = 'data/lookup_state.csv'
REGION_FILE = 'data/lookup_region.csv'

# %%
state_df = pd.read_csv(STATE_FILE)
state_df.head()
state_df.info()
# Out:
#    region_code state_abbr  state_fips_code  state_id      state_name
# 0  4            AK         2.0              1         Alaska
# 1  3            AL         1.0              2         Alabama
# 2  3            AR         5.0              3         Arkansas
# 3  99           AS         60.0             4         American Samoa
# 4  4            AZ         4.0              5         Arizona
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 5 columns):
# region_code        58 non-null int64
# state_abbr         58 non-null object
# state_fips_code    57 non-null float64
# state_id           58 non-null int64
# state_name         58 non-null object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.3+ KB

# %%
region_df = pd.read_csv(REGION_FILE)
region_df
# Out:
#    region_code       region_desc       region_name
# 0  0            U.S. Territories  U.S. Territories
# 1  1            Region I          Northeast
# 2  2            Region II         Midwest
# 3  3            Region III        South
# 4  4            Region IV         West
# 5  99           Other             Other

# %%
state_full_df = pd.merge(state_df, region_df, how='inner', on='region_code')
state_full_df.head()
# Out:
#    region_code state_abbr  state_fips_code  state_id  state_name region_desc  \
# 0  4            AK         2.0              1         Alaska      Region IV
# 1  4            AZ         4.0              5         Arizona     Region IV
# 2  4            CA         6.0              6         California  Region IV
# 3  4            CO         8.0              7         Colorado    Region IV
# 4  4            HI         15.0             15        Hawaii      Region IV
#
#   region_name
# 0  West
# 1  West
# 2  West
# 3  West
# 4  West

# %%
state_clean_df = state_full_df.sort_values('state_abbr').reset_index()
state_clean_df = state_clean_df[['state_abbr', 'state_name', 'region_name']]
state_clean_df.head(10)
state_clean_df.info()
# Out:
#   state_abbr            state_name region_name
# 0  AK         Alaska                West
# 1  AL         Alabama               South
# 2  AR         Arkansas              South
# 3  AS         American Samoa        Other
# 4  AZ         Arizona               West
# 5  CA         California            West
# 6  CO         Colorado              West
# 7  CT         Connecticut           Northeast
# 8  CZ         Canal Zone            Other
# 9  DC         District of Columbia  South
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
# state_abbr     58 non-null object
# state_name     58 non-null object
# region_name    58 non-null object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %% [markdown]
# ## Load Arrests

# %%
arrest_df = pd.read_csv(ARREST_FILE)
arrest_df = arrest_df.rename(columns={'count': 'arrests'})
arrest_df.head()
arrest_df.info()
# Out:
#   state  year  gender             offense  arrests
# 0  AK    2000  female  aggravated-assault  194
# 1  AK    2000  female  arson               3
# 2  AK    2000  female  burglary            49
# 3  AK    2000  female  curfew              1
# 4  AK    2000  female  disorderly-conduct  221
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51102 entries, 0 to 51101
# Data columns (total 5 columns):
# state      51102 non-null object
# year       51102 non-null int64
# gender     51102 non-null object
# offense    51102 non-null object
# arrests    51102 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 1.9+ MB

# %%
arrest_total_df = arrest_df.groupby(['state', 'year']).sum().sort_values(['state', 'year'])
arrest_total_df = arrest_total_df.reset_index()
arrest_total_df.head()
# Out:
#   state  year  arrests
# 0  AK    2000  21354
# 1  AK    2001  20267
# 2  AK    2002  19818
# 3  AK    2003  22746
# 4  AK    2004  21027

# %%
arrest_year_df = arrest_total_df.groupby(['year']).count().sort_values(['year']) 
arrest_year_df = arrest_year_df.rename(columns={'arrests': 'row_count'})
arrest_year_df
# Out:
#       state  row_count
# year
# 2000  48     48
# 2001  50     50
# 2002  50     50
# 2003  50     50
# 2004  50     50
# 2005  50     50
# 2006  50     50
# 2007  50     50
# 2008  50     50
# 2009  50     50
# 2010  50     50
# 2011  50     50
# 2012  50     50
# 2013  51     51
# 2014  51     51
# 2015  50     50
# 2016  50     50
# 2017  51     51
# 2018  51     51

# %% [markdown]
# ## Load Employment

# %%
employment_df = pd.read_csv(EMPLOYMENT_FILE)
employment_df.head()
employment_df.info()
# Out:
#    agency_ct  civilian_ct  year  female_civilian_ct  female_officer_ct  \
# 0  36         730.0        2010  474.0               106.0
# 1  35         710.0        2011  472.0               109.0
# 2  35         690.0        2012  453.0               109.0
# 3  33         634.0        2013  443.0               113.0
# 4  33         691.0        2014  456.0               116.0
#
#    female_total_ct  male_civilian_ct  male_officer_ct  male_total_ct  \
# 0  580.0            256.0             1152.0           1408.0
# 1  581.0            238.0             1215.0           1453.0
# 2  562.0            237.0             1221.0           1458.0
# 3  556.0            191.0             1248.0           1439.0
# 4  572.0            235.0             1202.0           1437.0
#
#    pe_ct_per_1000  population state_abbr state_name  total_pe_ct
# 0  2.79            711456      AK         Alaska     1988.0
# 1  2.80            725910      AK         Alaska     2034.0
# 2  2.75            735190      AK         Alaska     2020.0
# 3  2.70            739005      AK         Alaska     1995.0
# 4  2.71            740644      AK         Alaska     2009.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 14 columns):
# agency_ct             459 non-null int64
# civilian_ct           459 non-null float64
# year                  459 non-null int64
# female_civilian_ct    459 non-null float64
# female_officer_ct     459 non-null float64
# female_total_ct       459 non-null float64
# male_civilian_ct      459 non-null float64
# male_officer_ct       459 non-null float64
# male_total_ct         459 non-null float64
# pe_ct_per_1000        459 non-null float64
# population            459 non-null int64
# state_abbr            459 non-null object
# state_name            459 non-null object
# total_pe_ct           459 non-null float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 50.3+ KB

# %%
population_df = employment_df[['state_abbr', 'year', 'population']]
population_df.head()
# Out:
#   state_abbr  year  population
# 0  AK         2010  711456
# 1  AK         2011  725910
# 2  AK         2012  735190
# 3  AK         2013  739005
# 4  AK         2014  740644

# %%
population_df.groupby('year').count()
# Out:
#       state_abbr  population
# year
# 2010  51          51
# 2011  51          51
# 2012  51          51
# 2013  51          51
# 2014  51          51
# 2015  51          51
# 2016  51          51
# 2017  51          51
# 2018  51          51

# %% [markdown]
# ## Merge DataFrames

# %%
merge_1_df = pd.merge(arrest_total_df, population_df, how='inner', 
                      left_on=['state', 'year'], right_on=['state_abbr', 'year'])
merge_1_df.head()
# Out:
#   state  year  arrests state_abbr  population
# 0  AK    2010  26013    AK         711456
# 1  AK    2011  24738    AK         725910
# 2  AK    2012  18316    AK         735190
# 3  AK    2013  18876    AK         739005
# 4  AK    2014  15475    AK         740644

# %%
merge_2_df = pd.merge(merge_1_df, state_clean_df, how='inner', left_on=['state'], right_on=['state_abbr'])
merge_2_df.head()
# Out:
#   state  year  arrests state_abbr_x  population state_abbr_y state_name  \
# 0  AK    2010  26013    AK           711456      AK           Alaska
# 1  AK    2011  24738    AK           725910      AK           Alaska
# 2  AK    2012  18316    AK           735190      AK           Alaska
# 3  AK    2013  18876    AK           739005      AK           Alaska
# 4  AK    2014  15475    AK           740644      AK           Alaska
#
#   region_name
# 0  West
# 1  West
# 2  West
# 3  West
# 4  West

# %%
merge_df = merge_2_df[['region_name', 'state', 'year', 'arrests', 'population']]
merge_df.head()
merge_df.shape
# Out:
#   region_name state  year  arrests  population
# 0  West        AK    2010  26013    711456
# 1  West        AK    2011  24738    725910
# 2  West        AK    2012  18316    735190
# 3  West        AK    2013  18876    739005
# 4  West        AK    2014  15475    740644
# (451, 5)

# %%
merge_df['region_name'].value_counts()
# Out:
# South        145
# West         117
# Midwest      108
# Northeast    81
# Name: region_name, dtype: int64

# %% [markdown]
# ## Clean Merged Data

# %%
merge_df.boxplot(column=['arrests'])

# %%
merge_filter_df = merge_df.loc[merge_df['arrests']<330000]
merge_filter_df.head()
merge_filter_df.shape
# Out:
#   region_name state  year  arrests  population
# 0  West        AK    2010  26013    711456
# 1  West        AK    2011  24738    725910
# 2  West        AK    2012  18316    735190
# 3  West        AK    2013  18876    739005
# 4  West        AK    2014  15475    740644
# (425, 5)

# %%
merge_filter_df.boxplot(column=['arrests'])
